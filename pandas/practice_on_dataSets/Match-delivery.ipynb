# %% [markdown]
# ### performing the operation on the data sets
#
#                     - matches.csv
#                     - deliveries.csv
#
#     -- Merging on IPL dataset
#
# 1. Merge matches.csv and deliveries.csv on id and match id.
#
# 2. After merging, find the total number of records in the combined dataframe.
#
# 3. Verify whether every record in deliveries.csv has a matching match id in matches.csv.
#
# 4. Check for matches that have no deliveries recorded.
#
# 5. Merge both datasets using different join types (inner, left, right, outer) and compare their row counts.
#
# 6. Merge only selected columns from matches (like id, season, winner) with deliveries.
#
# 7. Merge datasets and rename overlapping columns properly (e.g., id →match id).
#
# 8. Ensure the merged dataframe has unique match id and inning combinations.
#
# 9. Sort the merged dataset by season and over.
#
# 10. Extract all deliveries for the 2016 IPL season using merged data.
#
# 11. Find all deliveries from matches where the city was "Mumbai".
#
# 12. List all deliveries bowled in matches won by "Mumbai Indians".
#
# 13. Find total runs scored in finals across all seasons.

# %% [markdown]
# ## let's import the libraries first

# %%
import numpy as np 
import pandas as pd

# %%
# setting to see whole columns because columns will collid to show only limited columns to prevent that from happening we use this.
pd.set_option("display.max_columns", None)

# %% [markdown]
# ***Importing the matches and deliverys data set first***

# %%
df_m = pd.read_csv(r"C:\Users\prath\FullStackDataScience\my own folder\database\data_files\matches.csv")
df_d = pd.read_csv(r"C:\Users\prath\FullStackDataScience\my own folder\database\data_files\deliveries.csv")

# %%
# checking the matches dataset 
df_m.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
df_d.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
## getting the coulumns of the match df 

df_m.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='str')

# %%
## getting the columns of the deliveries 

df_d.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='str')

# %%
### checking the shape of the mateches and delivery dataframe :

df_m.shape, df_d.shape
# Out:
# ((1095, 20), (260920, 17))

# %% [markdown]
# ### ***1. Merge matches.csv and deliveries.csv on id and match id.***

# %%
merged_df = df_m.merge(right=df_d, how="inner", left_on = "id", right_on="match_id")

# %%
merged_df.head(3)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 2  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
# 2          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  match_id  inning           batting_team  \
# 0  RE Koertzen    335982       1  Kolkata Knight Riders
# 1  RE Koertzen    335982       1  Kolkata Knight Riders
# 2  RE Koertzen    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
# 2  Royal Challengers Bangalore     0     3  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
# 2             0           1           1       wides          0
#
#   player_dismissed dismissal_kind fielder
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN
# 2              NaN            NaN     NaN

# %%
merged_df.shape
# Out:
# (260920, 37)

# %% [markdown]
# ### ***2. After merging, find the total number of records in the combined dataframe.***

# %%
print("total number of records : ", merged_df.shape[0])
# Out:
# total number of records :  260920

# %% [markdown]
# ### ***3. Verify whether every record in deliveries.csv has a matching match id in matches.csv.***

# %%
set(df_m["id"].value_counts().index) == set(df_d["match_id"].value_counts().index)
# Out:
# True

# %%
## second method :

s1 = set(df_m["id"])
s2 = set(df_d["match_id"])

# %%
## checking is set difference is none it means it has the same values in both of the set.
s1-s2
# Out:
# set()

# %%
# third method : 

# checking if both the sets is equals that means it contains same elements

s2 == s1
# Out:
# True

# %% [markdown]
# ### ***4. Check for matches that have no deliveries recorded.***

# %%
df_m[~df_m["id"].isin(df_d["match_id"])]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %% [markdown]
# ### ***5. Merge both datasets using different join types (inner, left, right, outer) and compare their row counts.***

# %%
# checking left join has how many columns 

left = pd.merge(df_m, df_d, how = "left", left_on= "id", right_on = "match_id").shape[0]
left2 = df_m.merge(df_d, how = "left", left_on = "id", right_on= "match_id").shape[0]
left, left2
# Out:
# (260920, 260920)

# %%
# checking inner join has how many columns 

inner = pd.merge(df_m, df_d, how = "inner", left_on= "id", right_on = "match_id").shape[0]
inner
# Out:
# 260920

# %%
right = pd.merge(df_m, df_d, how = "right", left_on= "id", right_on = "match_id").shape[0]
right
# Out:
# 260920

# %%
outer = pd.merge(df_m, df_d, how = "outer", left_on= "id", right_on = "match_id").shape[0]
outer
# Out:
# 260920

# %% [markdown]
# ### ***6. Merge only selected columns from matches (like id, season, winner) with deliveries.***

# %%
df = df_m[["id", "season", "winner"]]

merge = pd.merge(df, df_d, how = "inner", left_on= "id", right_on= "match_id")
merge.head(2)
# Out:
#        id   season                 winner  match_id  inning  \
# 0  335982  2007/08  Kolkata Knight Riders    335982       1
# 1  335982  2007/08  Kolkata Knight Riders    335982       1
#
#             batting_team                 bowling_team  over  ball  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
#
#         batter   bowler  non_striker  batsman_runs  extra_runs  total_runs  \
# 0   SC Ganguly  P Kumar  BB McCullum             0           1           1
# 1  BB McCullum  P Kumar   SC Ganguly             0           0           0
#
#   extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0     legbyes          0              NaN            NaN     NaN
# 1         NaN          0              NaN            NaN     NaN

# %%
# checking if only 3 from first columns + remaining all columns of second table is there or not 

merge.shape
# Out:
# (260920, 20)

# %% [markdown]
# ### ***7. Merge datasets and rename overlapping columns properly (e.g., id →match id).***

# %%
merge_ds = pd.merge(df_m, df_d, how = "inner", left_on="id", right_on = "match_id")
# print("before changing : \n")
# print(merge_ds.head())
print("after changing : \n")
merge_ds.rename(columns={"id" : "match_id"}).head(2)
# Out:
# after changing :
#    match_id   season       city        date match_type player_of_match  \
# 0    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  match_id  inning           batting_team  \
# 0  RE Koertzen    335982       1  Kolkata Knight Riders
# 1  RE Koertzen    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
#
#   player_dismissed dismissal_kind fielder
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN

# %%
merge_ds.shape
# Out:
# (260920, 37)

# %% [markdown]
# ###  ***8. Ensure the merged dataframe has unique match id and inning combinations.***

# %%
#  one way to do this using subset :
merge_ds.drop_duplicates(subset=["match_id", "inning"]).head(3)
# Out:
#          id   season        city        date match_type player_of_match  \
# 0    335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 124  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 225  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 124                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                      team2                  toss_winner toss_decision  \
# 0    Kolkata Knight Riders  Royal Challengers Bangalore         field
# 124  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 225    Chennai Super Kings          Chennai Super Kings           bat
#
#                     winner result  result_margin  target_runs  target_overs  \
# 0    Kolkata Knight Riders   runs          140.0        223.0          20.0
# 124  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 225    Chennai Super Kings   runs           33.0        241.0          20.0
#
#     super_over method    umpire1      umpire2  match_id  inning  \
# 0            N    NaN  Asad Rauf  RE Koertzen    335982       1
# 124          N    NaN  Asad Rauf  RE Koertzen    335982       2
# 225          N    NaN  MR Benson   SL Shastri    335983       1
#
#                     batting_team                 bowling_team  over  ball  \
# 0          Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 124  Royal Challengers Bangalore        Kolkata Knight Riders     0     1
# 225          Chennai Super Kings              Kings XI Punjab     0     1
#
#          batter    bowler  non_striker  batsman_runs  extra_runs  total_runs  \
# 0    SC Ganguly   P Kumar  BB McCullum             0           1           1
# 124    R Dravid  AB Dinda     W Jaffer             1           0           1
# 225    PA Patel     B Lee    ML Hayden             0           0           0
#
#     extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0       legbyes          0              NaN            NaN     NaN
# 124         NaN          0              NaN            NaN     NaN
# 225         NaN          0              NaN            NaN     NaN

# %%
merge_ds.drop_duplicates(subset=["match_id", "inning"]).shape
# Out:
# (2217, 37)

# %%
## there is one more way :

merge_ds[["match_id", "inning"]].drop_duplicates().head()
# Out:
#      match_id  inning
# 0      335982       1
# 124    335982       2
# 225    335983       1
# 349    335983       2
# 473    335984       1

# %%
merge_ds[["match_id", "inning"]].drop_duplicates().shape
# Out:
# (2217, 2)

# %% [markdown]
# ### ***9. Sort the merged dataset by season and over.***

# %%
sorted_season_over = merge_ds.sort_values(by = ["season", "over"])
sorted_season_over.head(2)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  match_id  inning           batting_team  \
# 0  RE Koertzen    335982       1  Kolkata Knight Riders
# 1  RE Koertzen    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
#
#   player_dismissed dismissal_kind fielder
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN

# %% [markdown]
# ### ***10. Extract all deliveries for the 2016 IPL season using merged data.***

# %%
merge_ds[merge_ds["season"] == "2016"].head(3)
# Out:
#             id season    city        date match_type player_of_match  \
# 122502  980901   2016  Mumbai  2016-04-09     League       AM Rahane
# 122503  980901   2016  Mumbai  2016-04-09     League       AM Rahane
# 122504  980901   2016  Mumbai  2016-04-09     League       AM Rahane
#
#                    venue           team1                    team2  \
# 122502  Wankhede Stadium  Mumbai Indians  Rising Pune Supergiants
# 122503  Wankhede Stadium  Mumbai Indians  Rising Pune Supergiants
# 122504  Wankhede Stadium  Mumbai Indians  Rising Pune Supergiants
#
#            toss_winner toss_decision                   winner   result  \
# 122502  Mumbai Indians           bat  Rising Pune Supergiants  wickets
# 122503  Mumbai Indians           bat  Rising Pune Supergiants  wickets
# 122504  Mumbai Indians           bat  Rising Pune Supergiants  wickets
#
#         result_margin  target_runs  target_overs super_over method  \
# 122502            9.0        122.0          20.0          N    NaN
# 122503            9.0        122.0          20.0          N    NaN
# 122504            9.0        122.0          20.0          N    NaN
#
#                 umpire1    umpire2  match_id  inning    batting_team  \
# 122502  HDPK Dharmasena  CK Nandan    980901       1  Mumbai Indians
# 122503  HDPK Dharmasena  CK Nandan    980901       1  Mumbai Indians
# 122504  HDPK Dharmasena  CK Nandan    980901       1  Mumbai Indians
#
#                    bowling_team  over  ball       batter    bowler  \
# 122502  Rising Pune Supergiants     0     1  LMP Simmons  RP Singh
# 122503  Rising Pune Supergiants     0     2    RG Sharma  RP Singh
# 122504  Rising Pune Supergiants     0     3    RG Sharma  RP Singh
#
#         non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 122502    RG Sharma             1           0           1         NaN
# 122503  LMP Simmons             0           0           0         NaN
# 122504  LMP Simmons             2           0           2         NaN
#
#         is_wicket player_dismissed dismissal_kind fielder
# 122502          0              NaN            NaN     NaN
# 122503          0              NaN            NaN     NaN
# 122504          0              NaN            NaN     NaN

# %%
merge_ds[merge_ds["season"] == "2016"].shape
# Out:
# (14096, 37)

# %% [markdown]
# ### ***11.Find all deliveries from matches where the city was "Mumbai".***

# %%
Mumbai_matches = df_m[["id", 'city']]
merged = Mumbai_matches.merge(df_d, left_on= "id", right_on = "match_id", how = "inner")
merged[merged["city"]=='Mumbai'].head(3)
# Out:
#          id    city  match_id  inning    batting_team  \
# 692  335985  Mumbai    335985       1  Mumbai Indians
# 693  335985  Mumbai    335985       1  Mumbai Indians
# 694  335985  Mumbai    335985       1  Mumbai Indians
#
#                     bowling_team  over  ball    batter   bowler  \
# 692  Royal Challengers Bangalore     0     1  L Ronchi  P Kumar
# 693  Royal Challengers Bangalore     0     2  L Ronchi  P Kumar
# 694  Royal Challengers Bangalore     0     3  L Ronchi  P Kumar
#
#        non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 692  ST Jayasuriya             0           0           0         NaN
# 693  ST Jayasuriya             4           0           4         NaN
# 694  ST Jayasuriya             0           0           0         NaN
#
#      is_wicket player_dismissed dismissal_kind fielder
# 692          0              NaN            NaN     NaN
# 693          0              NaN            NaN     NaN
# 694          0              NaN            NaN     NaN

# %%
merged[merged["city"]=='Mumbai'].shape
# Out:
# (41742, 19)

# %% [markdown]
# ### ***12.List all deliveries bowled in matches won by "Mumbai Indians".***

# %%
merged12 = df_m[["id", "winner"]].merge(df_d, left_on = "id", right_on = "match_id", how = "inner")
merged12[merged12["winner"] == "Mumbai Indians"].shape
# Out:
# (34629, 19)

# %%
merged12.head(3)
# Out:
#        id                 winner  match_id  inning           batting_team  \
# 0  335982  Kolkata Knight Riders    335982       1  Kolkata Knight Riders
# 1  335982  Kolkata Knight Riders    335982       1  Kolkata Knight Riders
# 2  335982  Kolkata Knight Riders    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
# 2  Royal Challengers Bangalore     0     3  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
# 2             0           1           1       wides          0
#
#   player_dismissed dismissal_kind fielder
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN
# 2              NaN            NaN     NaN

# %% [markdown]
# ### ***13.Find total runs scored in finals across all seasons.***

# %%
merge = df_m.merge(df_d, left_on = "id", right_on = "match_id", how = "inner")

# %%
df_m.match_type.unique()
# Out:
# <StringArray>
# [            'League',         'Semi Final',              'Final',
#  '3rd Place Play-Off',        'Qualifier 1',  'Elimination Final',
#         'Qualifier 2',         'Eliminator']
# Length: 8, dtype: str

# %%
merge[merge["match_type"] == "Final"]["total_runs"].sum()
# Out:
# np.int64(5556)

# %% [markdown]
# ### ***14.Filter all balls from matches decided by Duckworth-Lewis method (dl_applied == 1).***

# %%
merge.method.unique()
# Out:
# <StringArray>
# [nan, 'D/L']
# Length: 2, dtype: str

# %%
merge[merge["method"] == "D/L"].shape
# Out:
# (3646, 37)

# %%
merge[merge["method"] == "D/L"].head(3)
# Out:
#           id   season   city        date match_type   player_of_match  \
# 8852  336022  2007/08  Delhi  2008-05-17     League  DPMD Jayawardene
# 8853  336022  2007/08  Delhi  2008-05-17     League  DPMD Jayawardene
# 8854  336022  2007/08  Delhi  2008-05-17     League  DPMD Jayawardene
#
#                  venue             team1            team2       toss_winner  \
# 8852  Feroz Shah Kotla  Delhi Daredevils  Kings XI Punjab  Delhi Daredevils
# 8853  Feroz Shah Kotla  Delhi Daredevils  Kings XI Punjab  Delhi Daredevils
# 8854  Feroz Shah Kotla  Delhi Daredevils  Kings XI Punjab  Delhi Daredevils
#
#      toss_decision           winner result  result_margin  target_runs  \
# 8852           bat  Kings XI Punjab   runs            6.0         89.0
# 8853           bat  Kings XI Punjab   runs            6.0         89.0
# 8854           bat  Kings XI Punjab   runs            6.0         89.0
#
#       target_overs super_over method         umpire1      umpire2  match_id  \
# 8852           8.0          N    D/L  AV Jayaprakash  RE Koertzen    336022
# 8853           8.0          N    D/L  AV Jayaprakash  RE Koertzen    336022
# 8854           8.0          N    D/L  AV Jayaprakash  RE Koertzen    336022
#
#       inning      batting_team     bowling_team  over  ball     batter  \
# 8852       1  Delhi Daredevils  Kings XI Punjab     0     1  G Gambhir
# 8853       1  Delhi Daredevils  Kings XI Punjab     0     2  G Gambhir
# 8854       1  Delhi Daredevils  Kings XI Punjab     0     3  G Gambhir
#
#            bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 8852  S Sreesanth    V Sehwag             0           0           0
# 8853  S Sreesanth    V Sehwag             0           1           1
# 8854  S Sreesanth    V Sehwag             0           2           2
#
#      extras_type  is_wicket player_dismissed dismissal_kind fielder
# 8852         NaN          0              NaN            NaN     NaN
# 8853       wides          0              NaN            NaN     NaN
# 8854       wides          0              NaN            NaN     NaN

# %% [markdown]
# ### ***15.Find deliveries where the toss winner also won the match.***

# %%
merge[merge['toss_winner'] == merge['winner']].shape
# Out:
# (131334, 37)

# %%
merge[merge['toss_winner'] == merge['winner']].head(3)
# Out:
#          id   season        city        date match_type player_of_match  \
# 225  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 226  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 227  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                           venue            team1  \
# 225  Punjab Cricket Association Stadium, Mohali  Kings XI Punjab
# 226  Punjab Cricket Association Stadium, Mohali  Kings XI Punjab
# 227  Punjab Cricket Association Stadium, Mohali  Kings XI Punjab
#
#                    team2          toss_winner toss_decision  \
# 225  Chennai Super Kings  Chennai Super Kings           bat
# 226  Chennai Super Kings  Chennai Super Kings           bat
# 227  Chennai Super Kings  Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 225  Chennai Super Kings   runs           33.0        241.0          20.0
# 226  Chennai Super Kings   runs           33.0        241.0          20.0
# 227  Chennai Super Kings   runs           33.0        241.0          20.0
#
#     super_over method    umpire1     umpire2  match_id  inning  \
# 225          N    NaN  MR Benson  SL Shastri    335983       1
# 226          N    NaN  MR Benson  SL Shastri    335983       1
# 227          N    NaN  MR Benson  SL Shastri    335983       1
#
#             batting_team     bowling_team  over  ball    batter bowler  \
# 225  Chennai Super Kings  Kings XI Punjab     0     1  PA Patel  B Lee
# 226  Chennai Super Kings  Kings XI Punjab     0     2  PA Patel  B Lee
# 227  Chennai Super Kings  Kings XI Punjab     0     3  PA Patel  B Lee
#
#     non_striker  batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 225   ML Hayden             0           0           0         NaN          0
# 226   ML Hayden             0           0           0         NaN          0
# 227   ML Hayden             1           0           1         NaN          0
#
#     player_dismissed dismissal_kind fielder
# 225              NaN            NaN     NaN
# 226              NaN            NaN     NaN
# 227              NaN            NaN     NaN

# %% [markdown]
# ### ***16.Extract all wickets taken in matches played at "Eden Gardens".***

# %%
merge.is_wicket.unique()
# Out:
# array([0, 1])

# %%
res = merge[(merge['venue'] == "Eden Gardens")  & (merge["is_wicket"] == 1)]
res2 = merge[(merge['venue'] == "Eden Gardens, Kolkata")  & (merge["is_wicket"] == 1)]

# %%
res.shape, res2.shape
# Out:
# ((878, 37), (193, 37))

# %%
res.head(3)
# Out:
#          id   season     city        date match_type player_of_match  \
# 960  335986  2007/08  Kolkata  2008-04-20     League       DJ Hussey
# 967  335986  2007/08  Kolkata  2008-04-20     League       DJ Hussey
# 990  335986  2007/08  Kolkata  2008-04-20     League       DJ Hussey
#
#             venue                  team1            team2      toss_winner  \
# 960  Eden Gardens  Kolkata Knight Riders  Deccan Chargers  Deccan Chargers
# 967  Eden Gardens  Kolkata Knight Riders  Deccan Chargers  Deccan Chargers
# 990  Eden Gardens  Kolkata Knight Riders  Deccan Chargers  Deccan Chargers
#
#     toss_decision                 winner   result  result_margin  target_runs  \
# 960           bat  Kolkata Knight Riders  wickets            5.0        111.0
# 967           bat  Kolkata Knight Riders  wickets            5.0        111.0
# 990           bat  Kolkata Knight Riders  wickets            5.0        111.0
#
#      target_overs super_over method    umpire1      umpire2  match_id  inning  \
# 960          20.0          N    NaN  BF Bowden  K Hariharan    335986       1
# 967          20.0          N    NaN  BF Bowden  K Hariharan    335986       1
# 990          20.0          N    NaN  BF Bowden  K Hariharan    335986       1
#
#         batting_team           bowling_team  over  ball           batter  \
# 960  Deccan Chargers  Kolkata Knight Riders     3     2  Y Venugopal Rao
# 967  Deccan Chargers  Kolkata Knight Riders     4     3       VVS Laxman
# 990  Deccan Chargers  Kolkata Knight Riders     8     1     AC Gilchrist
#
#        bowler   non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 960  I Sharma  AC Gilchrist             0           0           0         NaN
# 967  AB Dinda  AC Gilchrist             0           0           0         NaN
# 990  M Kartik     A Symonds             0           0           0         NaN
#
#      is_wicket player_dismissed dismissal_kind          fielder
# 960          1  Y Venugopal Rao         caught         M Kartik
# 967          1       VVS Laxman         caught        LR Shukla
# 990          1     AC Gilchrist         caught  Mohammad Hafeez

# %%
res2.head(3)
# Out:
#              id season     city        date   match_type player_of_match  \
# 224988  1312197   2022  Kolkata  2022-05-24  Qualifier 1       DA Miller
# 225037  1312197   2022  Kolkata  2022-05-24  Qualifier 1       DA Miller
# 225065  1312197   2022  Kolkata  2022-05-24  Qualifier 1       DA Miller
#
#                         venue             team1           team2  \
# 224988  Eden Gardens, Kolkata  Rajasthan Royals  Gujarat Titans
# 225037  Eden Gardens, Kolkata  Rajasthan Royals  Gujarat Titans
# 225065  Eden Gardens, Kolkata  Rajasthan Royals  Gujarat Titans
#
#            toss_winner toss_decision          winner   result  result_margin  \
# 224988  Gujarat Titans         field  Gujarat Titans  wickets            7.0
# 225037  Gujarat Titans         field  Gujarat Titans  wickets            7.0
# 225065  Gujarat Titans         field  Gujarat Titans  wickets            7.0
#
#         target_runs  target_overs super_over method       umpire1    umpire2  \
# 224988        189.0          20.0          N    NaN  BNJ Oxenford  VK Sharma
# 225037        189.0          20.0          N    NaN  BNJ Oxenford  VK Sharma
# 225065        189.0          20.0          N    NaN  BNJ Oxenford  VK Sharma
#
#         match_id  inning      batting_team    bowling_team  over  ball  \
# 224988   1312197       1  Rajasthan Royals  Gujarat Titans     1     6
# 225037   1312197       1  Rajasthan Royals  Gujarat Titans     9     5
# 225065   1312197       1  Rajasthan Royals  Gujarat Titans    14     1
#
#              batter         bowler non_striker  batsman_runs  extra_runs  \
# 224988  YBK Jaiswal     Yash Dayal  JC Buttler             0           0
# 225037    SV Samson  R Sai Kishore  JC Buttler             0           0
# 225065   D Padikkal      HH Pandya  JC Buttler             0           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 224988           0         NaN          1      YBK Jaiswal         caught
# 225037           0         NaN          1        SV Samson         caught
# 225065           0         NaN          1       D Padikkal         bowled
#
#           fielder
# 224988    WP Saha
# 225037  AS Joseph
# 225065        NaN

# %% [markdown]
# ### ***17.Get all deliveries of Super Overs using merged data.***

# %%
Super_Over = merge[merge["super_over"] == "Y"]

# %%
Super_Over.shape
# Out:
# (3634, 37)

# %%
Super_Over.head(3)
# Out:
#            id season       city        date match_type player_of_match  \
# 15161  392190   2009  Cape Town  2009-04-23     League       YK Pathan
# 15162  392190   2009  Cape Town  2009-04-23     League       YK Pathan
# 15163  392190   2009  Cape Town  2009-04-23     League       YK Pathan
#
#           venue                  team1             team2  \
# 15161  Newlands  Kolkata Knight Riders  Rajasthan Royals
# 15162  Newlands  Kolkata Knight Riders  Rajasthan Royals
# 15163  Newlands  Kolkata Knight Riders  Rajasthan Royals
#
#                  toss_winner toss_decision            winner result  \
# 15161  Kolkata Knight Riders         field  Rajasthan Royals    tie
# 15162  Kolkata Knight Riders         field  Rajasthan Royals    tie
# 15163  Kolkata Knight Riders         field  Rajasthan Royals    tie
#
#        result_margin  target_runs  target_overs super_over method    umpire1  \
# 15161            NaN        151.0          20.0          Y    NaN  MR Benson
# 15162            NaN        151.0          20.0          Y    NaN  MR Benson
# 15163            NaN        151.0          20.0          Y    NaN  MR Benson
#
#          umpire2  match_id  inning      batting_team           bowling_team  \
# 15161  M Erasmus    392190       1  Rajasthan Royals  Kolkata Knight Riders
# 15162  M Erasmus    392190       1  Rajasthan Royals  Kolkata Knight Riders
# 15163  M Erasmus    392190       1  Rajasthan Royals  Kolkata Knight Riders
#
#        over  ball       batter    bowler  non_striker  batsman_runs  \
# 15161     0     1     GC Smith  I Sharma  PC Valthaty             0
# 15162     0     2     GC Smith  I Sharma  PC Valthaty             0
# 15163     0     3  PC Valthaty  I Sharma     GC Smith             1
#
#        extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 15161           0           0         NaN          0              NaN
# 15162           1           1     legbyes          0              NaN
# 15163           0           1         NaN          0              NaN
#
#       dismissal_kind fielder
# 15161            NaN     NaN
# 15162            NaN     NaN
# 15163            NaN     NaN

# %% [markdown]
# ### ***18.Filter matches where the toss decision was "field" and list first 10 deliveries.***

# %%
Field = merge[merge['toss_decision'] == "field"].head(10)

# %%
Field
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 5  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 6  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 7  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 8  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 9  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 3  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 4  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 5  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 6  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 7  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 8  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 9  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 2  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 3  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 4  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 5  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 6  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 7  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 8  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 9  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
# 2          140.0        223.0          20.0          N    NaN  Asad Rauf
# 3          140.0        223.0          20.0          N    NaN  Asad Rauf
# 4          140.0        223.0          20.0          N    NaN  Asad Rauf
# 5          140.0        223.0          20.0          N    NaN  Asad Rauf
# 6          140.0        223.0          20.0          N    NaN  Asad Rauf
# 7          140.0        223.0          20.0          N    NaN  Asad Rauf
# 8          140.0        223.0          20.0          N    NaN  Asad Rauf
# 9          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  match_id  inning           batting_team  \
# 0  RE Koertzen    335982       1  Kolkata Knight Riders
# 1  RE Koertzen    335982       1  Kolkata Knight Riders
# 2  RE Koertzen    335982       1  Kolkata Knight Riders
# 3  RE Koertzen    335982       1  Kolkata Knight Riders
# 4  RE Koertzen    335982       1  Kolkata Knight Riders
# 5  RE Koertzen    335982       1  Kolkata Knight Riders
# 6  RE Koertzen    335982       1  Kolkata Knight Riders
# 7  RE Koertzen    335982       1  Kolkata Knight Riders
# 8  RE Koertzen    335982       1  Kolkata Knight Riders
# 9  RE Koertzen    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
# 2  Royal Challengers Bangalore     0     3  BB McCullum  P Kumar   SC Ganguly
# 3  Royal Challengers Bangalore     0     4  BB McCullum  P Kumar   SC Ganguly
# 4  Royal Challengers Bangalore     0     5  BB McCullum  P Kumar   SC Ganguly
# 5  Royal Challengers Bangalore     0     6  BB McCullum  P Kumar   SC Ganguly
# 6  Royal Challengers Bangalore     0     7  BB McCullum  P Kumar   SC Ganguly
# 7  Royal Challengers Bangalore     1     1  BB McCullum   Z Khan   SC Ganguly
# 8  Royal Challengers Bangalore     1     2  BB McCullum   Z Khan   SC Ganguly
# 9  Royal Challengers Bangalore     1     3  BB McCullum   Z Khan   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
# 2             0           1           1       wides          0
# 3             0           0           0         NaN          0
# 4             0           0           0         NaN          0
# 5             0           0           0         NaN          0
# 6             0           1           1     legbyes          0
# 7             0           0           0         NaN          0
# 8             4           0           4         NaN          0
# 9             4           0           4         NaN          0
#
#   player_dismissed dismissal_kind fielder
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN
# 2              NaN            NaN     NaN
# 3              NaN            NaN     NaN
# 4              NaN            NaN     NaN
# 5              NaN            NaN     NaN
# 6              NaN            NaN     NaN
# 7              NaN            NaN     NaN
# 8              NaN            NaN     NaN
# 9              NaN            NaN     NaN

# %% [markdown]
# ### ***19.Show all balls bowled in matches that had a tie result.***

# %%
tie = merge[merge['result'] == 'tie']

# %%
tie.head(3)
# Out:
#            id season       city        date match_type player_of_match  \
# 15161  392190   2009  Cape Town  2009-04-23     League       YK Pathan
# 15162  392190   2009  Cape Town  2009-04-23     League       YK Pathan
# 15163  392190   2009  Cape Town  2009-04-23     League       YK Pathan
#
#           venue                  team1             team2  \
# 15161  Newlands  Kolkata Knight Riders  Rajasthan Royals
# 15162  Newlands  Kolkata Knight Riders  Rajasthan Royals
# 15163  Newlands  Kolkata Knight Riders  Rajasthan Royals
#
#                  toss_winner toss_decision            winner result  \
# 15161  Kolkata Knight Riders         field  Rajasthan Royals    tie
# 15162  Kolkata Knight Riders         field  Rajasthan Royals    tie
# 15163  Kolkata Knight Riders         field  Rajasthan Royals    tie
#
#        result_margin  target_runs  target_overs super_over method    umpire1  \
# 15161            NaN        151.0          20.0          Y    NaN  MR Benson
# 15162            NaN        151.0          20.0          Y    NaN  MR Benson
# 15163            NaN        151.0          20.0          Y    NaN  MR Benson
#
#          umpire2  match_id  inning      batting_team           bowling_team  \
# 15161  M Erasmus    392190       1  Rajasthan Royals  Kolkata Knight Riders
# 15162  M Erasmus    392190       1  Rajasthan Royals  Kolkata Knight Riders
# 15163  M Erasmus    392190       1  Rajasthan Royals  Kolkata Knight Riders
#
#        over  ball       batter    bowler  non_striker  batsman_runs  \
# 15161     0     1     GC Smith  I Sharma  PC Valthaty             0
# 15162     0     2     GC Smith  I Sharma  PC Valthaty             0
# 15163     0     3  PC Valthaty  I Sharma     GC Smith             1
#
#        extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 15161           0           0         NaN          0              NaN
# 15162           1           1     legbyes          0              NaN
# 15163           0           1         NaN          0              NaN
#
#       dismissal_kind fielder
# 15161            NaN     NaN
# 15162            NaN     NaN
# 15163            NaN     NaN

# %%
tie.shape
# Out:
# (3634, 37)

# %% [markdown]
# ### ***20.Find all deliveries bowled by “Bumrah” in matches where his team lost.***

# %%
Bumrah_lost = merge[(merge["bowler"] == "JJ Bumrah") & (merge["winner"] != "Mumbai Indians")]

# %%
Bumrah_lost.shape
# Out:
# (1523, 37)

# %%
Bumrah_lost.head(3)
# Out:
#            id season       city        date match_type player_of_match  \
# 76637  597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 76638  597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 76639  597999   2013  Bangalore  2013-04-04     League        CH Gayle
#
#                        venue                        team1           team2  \
# 76637  M Chinnaswamy Stadium  Royal Challengers Bangalore  Mumbai Indians
# 76638  M Chinnaswamy Stadium  Royal Challengers Bangalore  Mumbai Indians
# 76639  M Chinnaswamy Stadium  Royal Challengers Bangalore  Mumbai Indians
#
#           toss_winner toss_decision                       winner result  \
# 76637  Mumbai Indians         field  Royal Challengers Bangalore   runs
# 76638  Mumbai Indians         field  Royal Challengers Bangalore   runs
# 76639  Mumbai Indians         field  Royal Challengers Bangalore   runs
#
#        result_margin  target_runs  target_overs super_over method  \
# 76637            2.0        157.0          20.0          N    NaN
# 76638            2.0        157.0          20.0          N    NaN
# 76639            2.0        157.0          20.0          N    NaN
#
#            umpire1        umpire2  match_id  inning  \
# 76637  VA Kulkarni  C Shamshuddin    597999       1
# 76638  VA Kulkarni  C Shamshuddin    597999       1
# 76639  VA Kulkarni  C Shamshuddin    597999       1
#
#                       batting_team    bowling_team  over  ball   batter  \
# 76637  Royal Challengers Bangalore  Mumbai Indians     4     1  V Kohli
# 76638  Royal Challengers Bangalore  Mumbai Indians     4     2  V Kohli
# 76639  Royal Challengers Bangalore  Mumbai Indians     4     3  V Kohli
#
#           bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 76637  JJ Bumrah    CH Gayle             4           0           4
# 76638  JJ Bumrah    CH Gayle             4           0           4
# 76639  JJ Bumrah    CH Gayle             0           0           0
#
#       extras_type  is_wicket player_dismissed dismissal_kind fielder
# 76637         NaN          0              NaN            NaN     NaN
# 76638         NaN          0              NaN            NaN     NaN
# 76639         NaN          0              NaN            NaN     NaN

# %% [markdown]
# ### ***22.Add a column is_final which marks 1 if the match was a final (based on match_id of last match in each season).***

# %%
df_m["match_type"].unique()
# Out:
# <StringArray>
# [            'League',         'Semi Final',              'Final',
#  '3rd Place Play-Off',        'Qualifier 1',  'Elimination Final',
#         'Qualifier 2',         'Eliminator']
# Length: 8, dtype: str

# %%
matches = df_m.iloc[:, :]

# %%
matches["is_final"] = matches["match_type"].apply(lambda x : 1 if x == "Final" else 0)

# %%
df_m[df_m["match_type"] == "Final"].head(2)
# Out:
#          id   season          city        date match_type player_of_match  \
# 57   336040  2007/08        Mumbai  2008-06-01      Final       YK Pathan
# 114  392239     2009  Johannesburg  2009-05-24      Final        A Kumble
#
#                           venue                        team1  \
# 57   Dr DY Patil Sports Academy          Chennai Super Kings
# 114       New Wanderers Stadium  Royal Challengers Bangalore
#
#                 team2                  toss_winner toss_decision  \
# 57   Rajasthan Royals             Rajasthan Royals         field
# 114   Deccan Chargers  Royal Challengers Bangalore         field
#
#                winner   result  result_margin  target_runs  target_overs  \
# 57   Rajasthan Royals  wickets            3.0        164.0          20.0
# 114   Deccan Chargers     runs            6.0        144.0          20.0
#
#     super_over method      umpire1      umpire2
# 57           N    NaN    BF Bowden  RE Koertzen
# 114          N    NaN  RE Koertzen   SJA Taufel

# %%
matches[matches["match_type"] == "Final"].head(3)
# Out:
#          id   season          city        date match_type player_of_match  \
# 57   336040  2007/08        Mumbai  2008-06-01      Final       YK Pathan
# 114  392239     2009  Johannesburg  2009-05-24      Final        A Kumble
# 174  419165  2009/10        Mumbai  2010-04-25      Final        SK Raina
#
#                           venue                        team1  \
# 57   Dr DY Patil Sports Academy          Chennai Super Kings
# 114       New Wanderers Stadium  Royal Challengers Bangalore
# 174  Dr DY Patil Sports Academy          Chennai Super Kings
#
#                 team2                  toss_winner toss_decision  \
# 57   Rajasthan Royals             Rajasthan Royals         field
# 114   Deccan Chargers  Royal Challengers Bangalore         field
# 174    Mumbai Indians          Chennai Super Kings           bat
#
#                   winner   result  result_margin  target_runs  target_overs  \
# 57      Rajasthan Royals  wickets            3.0        164.0          20.0
# 114      Deccan Chargers     runs            6.0        144.0          20.0
# 174  Chennai Super Kings     runs           22.0        169.0          20.0
#
#     super_over method      umpire1      umpire2  is_final
# 57           N    NaN    BF Bowden  RE Koertzen         1
# 114          N    NaN  RE Koertzen   SJA Taufel         1
# 174          N    NaN  RE Koertzen   SJA Taufel         1

# %% [markdown]
# ### ***23.Add a new column combining batsman and bowler as a single string "matchup".***

# %%
combined = matches.merge(df_d, how = "inner", left_on = "id", right_on = "match_id")

# %%
combined.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_id', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler',
#        'non_striker', 'batsman_runs', 'extra_runs', 'total_runs',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder'],
#       dtype='str')

# %%
combined["matchup"] = combined["batter"] + "v/s" + combined["bowler"]

# %%
combined.head(3)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 2  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
# 2          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  is_final  match_id  inning           batting_team  \
# 0  RE Koertzen         0    335982       1  Kolkata Knight Riders
# 1  RE Koertzen         0    335982       1  Kolkata Knight Riders
# 2  RE Koertzen         0    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
# 2  Royal Challengers Bangalore     0     3  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
# 2             0           1           1       wides          0
#
#   player_dismissed dismissal_kind fielder                matchup
# 0              NaN            NaN     NaN   SC Gangulyv/sP Kumar
# 1              NaN            NaN     NaN  BB McCullumv/sP Kumar
# 2              NaN            NaN     NaN  BB McCullumv/sP Kumar

# %% [markdown]
# ### ***24.Create a new column run_type that classifies each ball as “boundary”, “dot”, or “other”.***

# %%
combined.total_runs.unique()
# Out:
# array([1, 0, 4, 6, 5, 2, 3, 7])

# %%
def run_type(x) :
    if x in [4, 6] :
        return "boundary"
    elif x == 0 :
        return 'dot' 
    elif x == 1 :
        return "single"
    elif x == 2 :
        return "double"
    else :
        return "other"

# %%
combined["run_type"] = combined.total_runs.apply(run_type)

# %%
combined.head(3)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 2  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
# 2          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  is_final  match_id  inning           batting_team  \
# 0  RE Koertzen         0    335982       1  Kolkata Knight Riders
# 1  RE Koertzen         0    335982       1  Kolkata Knight Riders
# 2  RE Koertzen         0    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
# 2  Royal Challengers Bangalore     0     3  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
# 2             0           1           1       wides          0
#
#   player_dismissed dismissal_kind fielder                matchup run_type
# 0              NaN            NaN     NaN   SC Gangulyv/sP Kumar   single
# 1              NaN            NaN     NaN  BB McCullumv/sP Kumar      dot
# 2              NaN            NaN     NaN  BB McCullumv/sP Kumar   single

# %% [markdown]
# ### ***25.Add a new boolean column powerplay_ball for overs ≤ 6.***

# %%
combined["power_ball"] = combined["over"] <= 6

# %%
combined.head(2)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  is_final  match_id  inning           batting_team  \
# 0  RE Koertzen         0    335982       1  Kolkata Knight Riders
# 1  RE Koertzen         0    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
#
#   player_dismissed dismissal_kind fielder                matchup run_type  \
# 0              NaN            NaN     NaN   SC Gangulyv/sP Kumar   single
# 1              NaN            NaN     NaN  BB McCullumv/sP Kumar      dot
#
#    power_ball
# 0        True
# 1        True

# %% [markdown]
# ### ***26.Add a column showing cumulative wickets lost by each batting team in a match.***

# %%
delivery = df_d.iloc[:, :]

# %%
delivery["cum_wicket"] = delivery.groupby(["match_id", "batting_team"])["is_wicket"].cumsum()

# %%
delivery[delivery["cum_wicket"] == 5]
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 174       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 175       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 176       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 321       335983       1          Chennai Super Kings        Kings XI Punjab
# 322       335983       1          Chennai Super Kings        Kings XI Punjab
# ...          ...     ...                          ...                    ...
# 260806   1426312       1          Sunrisers Hyderabad  Kolkata Knight Riders
# 260807   1426312       1          Sunrisers Hyderabad  Kolkata Knight Riders
# 260808   1426312       1          Sunrisers Hyderabad  Kolkata Knight Riders
# 260809   1426312       1          Sunrisers Hyderabad  Kolkata Knight Riders
# 260810   1426312       1          Sunrisers Hyderabad  Kolkata Knight Riders
#
#         over  ball         batter      bowler    non_striker  batsman_runs  \
# 174        7     5     MV Boucher  SC Ganguly       CL White             0
# 175        7     6       CL White  SC Ganguly        B Akhil             0
# 176        8     1        B Akhil  AB Agarkar       CL White             0
# 321       15     3       JDP Oram   IK Pathan     MEK Hussey             0
# 322       15     4    S Badrinath   IK Pathan     MEK Hussey             0
# ...      ...   ...            ...         ...            ...           ...
# 260806    10     6  Shahbaz Ahmed  AD Russell      H Klaasen             6
# 260807    11     1      H Klaasen    CV Varun  Shahbaz Ahmed             0
# 260808    11     2      H Klaasen    CV Varun  Shahbaz Ahmed             1
# 260809    11     3  Shahbaz Ahmed    CV Varun      H Klaasen             0
# 260810    11     4  Shahbaz Ahmed    CV Varun      H Klaasen             0
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 174              0           0         NaN          1       MV Boucher
# 175              0           0         NaN          0              NaN
# 176              0           0         NaN          0              NaN
# 321              0           0         NaN          1         JDP Oram
# 322              0           0         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 260806           0           6         NaN          0              NaN
# 260807           0           0         NaN          0              NaN
# 260808           0           1         NaN          0              NaN
# 260809           0           0         NaN          0              NaN
# 260810           0           0         NaN          0              NaN
#
#        dismissal_kind   fielder  cum_wicket
# 174            caught  M Kartik           5
# 175               NaN       NaN           5
# 176               NaN       NaN           5
# 321            bowled       NaN           5
# 322               NaN       NaN           5
# ...               ...       ...         ...
# 260806            NaN       NaN           5
# 260807            NaN       NaN           5
# 260808            NaN       NaN           5
# 260809            NaN       NaN           5
# 260810            NaN       NaN           5
#
# [18778 rows x 18 columns]

# %%
delivery.head(3)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
#
#    cum_wicket
# 0           0
# 1           0
# 2           0

# %% [markdown]
# ### ***27.Replace dismissal_kind NaN values with “not out”.***

# %%
combined.dismissal_kind.unique()
# Out:
# <StringArray>
# [                    nan,                'caught',                'bowled',
#                'run out',                   'lbw',          'retired hurt',
#                'stumped',     'caught and bowled',            'hit wicket',
#  'obstructing the field',           'retired out']
# Length: 11, dtype: str

# %%
combined.dismissal_kind.fillna("not out")
# Out:
# 0         not out
# 1         not out
# 2         not out
# 3         not out
# 4         not out
#            ...
# 260915    not out
# 260916    not out
# 260917    not out
# 260918    not out
# 260919    not out
# Name: dismissal_kind, Length: 260920, dtype: str

# %%
combined["dismissal_kind"] = combined["dismissal_kind"].fillna("not out")

# %%
combined.head(2)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
# 1          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2  is_final  match_id  inning           batting_team  \
# 0  RE Koertzen         0    335982       1  Kolkata Knight Riders
# 1  RE Koertzen         0    335982       1  Kolkata Knight Riders
#
#                   bowling_team  over  ball       batter   bowler  non_striker  \
# 0  Royal Challengers Bangalore     0     1   SC Ganguly  P Kumar  BB McCullum
# 1  Royal Challengers Bangalore     0     2  BB McCullum  P Kumar   SC Ganguly
#
#    batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0             0           1           1     legbyes          0
# 1             0           0           0         NaN          0
#
#   player_dismissed dismissal_kind fielder                matchup run_type  \
# 0              NaN        not out     NaN   SC Gangulyv/sP Kumar   single
# 1              NaN        not out     NaN  BB McCullumv/sP Kumar      dot
#
#    power_ball
# 0        True
# 1        True

# %%
combined.dismissal_kind.unique()
# Out:
# <StringArray>
# [              'not out',                'caught',                'bowled',
#                'run out',                   'lbw',          'retired hurt',
#                'stumped',     'caught and bowled',            'hit wicket',
#  'obstructing the field',           'retired out']
# Length: 11, dtype: str

# %% [markdown]
# ### ***28.Add column inning_type with values “first innings” or “second innings”.***

# %%
delivery.inning.unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
def inning_type (x) :
    if x == 1 :
        return "first innings"
    if x == 2 :
        return "second innings"
    if x in [3, 4] :
        return "Super Over"
    if x in [5, 6] :
        return "Second Super Over"

# %%
delivery["inning_type"] = delivery["inning"].apply(inning_type)

# %%
delivery.head(2)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
#
#    cum_wicket    inning_type
# 0           0  first innings
# 1           0  first innings

# %% [markdown]
# ### ***29.Add column match_label combining season and city name.***

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final'],
#       dtype='str')

# %%
matches["match_label"] = matches["season"] + " - " + matches["city"]

# %%
matches.head(3)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
# 2       Rajasthan Royals             Rajasthan Royals           bat
#
#                   winner   result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders     runs          140.0        223.0          20.0
# 1    Chennai Super Kings     runs           33.0        241.0          20.0
# 2       Delhi Daredevils  wickets            9.0        130.0          20.0
#
#   super_over method    umpire1         umpire2  is_final           match_label
# 0          N    NaN  Asad Rauf     RE Koertzen         0   2007/08 - Bangalore
# 1          N    NaN  MR Benson      SL Shastri         0  2007/08 - Chandigarh
# 2          N    NaN  Aleem Dar  GA Pratapkumar         0       2007/08 - Delhi

# %% [markdown]
# ### ***30.Compute total runs scored by each team in each season.***

# %%
combined.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_id', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler',
#        'non_striker', 'batsman_runs', 'extra_runs', 'total_runs',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder', 'matchup', 'run_type', 'power_ball'],
#       dtype='str')

# %%
combined.groupby(by = ["season", "batting_team"])["total_runs"].sum().reset_index()
# Out:
#       season                 batting_team  total_runs
# 0    2007/08          Chennai Super Kings        2520
# 1    2007/08              Deccan Chargers        2229
# 2    2007/08             Delhi Daredevils        2118
# 3    2007/08              Kings XI Punjab        2464
# 4    2007/08        Kolkata Knight Riders        1942
# ..       ...                          ...         ...
# 141     2024               Mumbai Indians        2568
# 142     2024                 Punjab Kings        2487
# 143     2024             Rajasthan Royals        2647
# 144     2024  Royal Challengers Bengaluru        2930
# 145     2024          Sunrisers Hyderabad        3052
#
# [146 rows x 3 columns]

# %% [markdown]
# ### ***31. Calculate total wickets taken by each bowler acroos all seasons.***

# %% [markdown]
#             -  checking for whole calculated seasons

# %%
combined.bowler.unique()
# Out:
# <StringArray>
# [      'P Kumar',        'Z Khan',     'AA Noffke',     'JH Kallis',
#       'SB Joshi',      'CL White',      'AB Dinda',      'I Sharma',
#     'AB Agarkar',    'SC Ganguly',
#  ...
#     'N Thushara',   'LB Williams',    'RJ Gleeson',     'MJ Suthar',
#       'A Kamboj',  'V Viyaskanth',   'V Kaverappa', 'Gulbadin Naib',
#      'N Wadhera', 'Atharva Taide']
# Length: 530, dtype: str

# %%
combined.is_wicket.unique()
# Out:
# array([0, 1])

# %%
combined.groupby(by = "bowler")["is_wicket"].sum().reset_index()
# Out:
#              bowler  is_wicket
# 0    A Ashish Reddy         19
# 1          A Badoni          2
# 2        A Chandila         11
# 3       A Choudhary          5
# 4       A Dananjaya          0
# ..              ...        ...
# 525      Yash Dayal         31
# 526     Yash Thakur         27
# 527   Yudhvir Singh          4
# 528    Yuvraj Singh         39
# 529          Z Khan        119
#
# [530 rows x 2 columns]

# %%
combined[(combined["bowler"] == "Z Khan") & (combined["is_wicket"] == 1)].shape[0]
# Out:
# 119

# %% [markdown]
#             - now season wise wicket calculation

# %%
wicket = combined.groupby(by = ["season", "bowler"])["is_wicket"].sum().reset_index()

# %%
wicket
# Out:
#        season             bowler  is_wicket
# 0     2007/08           A Kumble          8
# 1     2007/08           A Mishra         11
# 2     2007/08            A Nehra         14
# 3     2007/08              A Nel          1
# 4     2007/08          A Symonds          0
# ...       ...                ...        ...
# 1943     2024  Washington Sundar          1
# 1944     2024          YS Chahal         19
# 1945     2024         Yash Dayal         16
# 1946     2024        Yash Thakur         12
# 1947     2024      Yudhvir Singh          1
#
# [1948 rows x 3 columns]

# %% [markdown]
# ### ***32. Find Total number of matches played per city.***

# %%
combined.city.unique()
# Out:
# <StringArray>
# [     'Bangalore',     'Chandigarh',          'Delhi',         'Mumbai',
#         'Kolkata',         'Jaipur',      'Hyderabad',        'Chennai',
#       'Cape Town', 'Port Elizabeth',         'Durban',      'Centurion',
#     'East London',   'Johannesburg',      'Kimberley',   'Bloemfontein',
#       'Ahmedabad',        'Cuttack',         'Nagpur',     'Dharamsala',
#           'Kochi',         'Indore',  'Visakhapatnam',           'Pune',
#          'Raipur',         'Ranchi',      'Abu Dhabi',              nan,
#          'Rajkot',         'Kanpur',      'Bengaluru',          'Dubai',
#         'Sharjah',    'Navi Mumbai',        'Lucknow',       'Guwahati',
#          'Mohali']
# Length: 37, dtype: str

# %%
combined.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_id', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler',
#        'non_striker', 'batsman_runs', 'extra_runs', 'total_runs',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder', 'matchup', 'run_type', 'power_ball'],
#       dtype='str')

# %%
combined.groupby(by = ["city"])["id"].count().reset_index()
# Out:
#               city     id
# 0        Abu Dhabi   8799
# 1        Ahmedabad   8553
# 2        Bangalore  14907
# 3        Bengaluru   6917
# 4     Bloemfontein    500
# 5        Cape Town   1539
# 6        Centurion   2866
# 7       Chandigarh  14476
# 8          Chennai  20706
# 9          Cuttack   1695
# 10           Delhi  21269
# 11      Dharamsala   3141
# 12           Dubai   3149
# 13          Durban   3643
# 14     East London    715
# 15        Guwahati    739
# 16       Hyderabad  18355
# 17          Indore   1965
# 18          Jaipur  13520
# 19    Johannesburg   1940
# 20          Kanpur    921
# 21       Kimberley    726
# 22           Kochi   1155
# 23         Kolkata  21846
# 24         Lucknow   3283
# 25          Mohali   1235
# 26          Mumbai  41742
# 27          Nagpur    742
# 28     Navi Mumbai   2188
# 29  Port Elizabeth   1677
# 30            Pune  12239
# 31          Raipur   1431
# 32          Rajkot   2381
# 33          Ranchi   1671
# 34         Sharjah   2355
# 35   Visakhapatnam   3537

# %% [markdown]
# ### ***33. Get the average runs per over for each team in the 2017 season.***

# %%
combined.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_id', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler',
#        'non_striker', 'batsman_runs', 'extra_runs', 'total_runs',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder', 'matchup', 'run_type', 'power_ball'],
#       dtype='str')

# %%
combined.groupby(by = ["id", "over", "batting_team"])["total_runs"]
# Out:
# id       over  batting_team
# 335982   0     Kolkata Knight Riders          0.428571
#                Royal Challengers Bangalore    0.571429
#          1     Kolkata Knight Riders          3.000000
#                Royal Challengers Bangalore    0.833333
#          2     Kolkata Knight Riders          1.000000
#                                                 ...
# 1426312  14    Sunrisers Hyderabad            0.000000
#          15    Sunrisers Hyderabad            1.333333
#          16    Sunrisers Hyderabad            1.666667
#          17    Sunrisers Hyderabad            0.833333
#          18    Sunrisers Hyderabad            0.000000
# Name: total_runs, Length: 42180, dtype: float64

# %% [markdown]
# ### ***34. Find the top 5 batsmen with highest total runs in finals.***

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_label'],
#       dtype='str')

# %%
matches.match_label.unique()
# Out:
# <StringArray>
# [  '2007/08 - Bangalore',  '2007/08 - Chandigarh',       '2007/08 - Delhi',
#       '2007/08 - Mumbai',     '2007/08 - Kolkata',      '2007/08 - Jaipur',
#    '2007/08 - Hyderabad',     '2007/08 - Chennai',      '2009 - Cape Town',
#  '2009 - Port Elizabeth',
#  ...
#          '2024 - Jaipur',      '2024 - Ahmedabad',      '2024 - Bengaluru',
#       '2024 - Hyderabad',        '2024 - Lucknow',  '2024 - Visakhapatnam',
#          '2024 - Mumbai',          '2024 - Delhi',     '2024 - Dharamsala',
#        '2024 - Guwahati']
# Length: 164, dtype: str

# %%
df_d.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='str')

# %%
df_m.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='str')

# %%
df_m.match_type.unique()
# Out:
# <StringArray>
# [            'League',         'Semi Final',              'Final',
#  '3rd Place Play-Off',        'Qualifier 1',  'Elimination Final',
#         'Qualifier 2',         'Eliminator']
# Length: 8, dtype: str

# %%
combined.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_id', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler',
#        'non_striker', 'batsman_runs', 'extra_runs', 'total_runs',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder', 'matchup', 'run_type', 'power_ball'],
#       dtype='str')

# %%
combined[combined["run_type"] == "other"].head(3)
# Out:
#          id   season        city        date match_type player_of_match  \
# 19   335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 239  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 676  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                           venue                        team1  \
# 19                        M Chinnaswamy Stadium  Royal Challengers Bangalore
# 239  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 676                            Feroz Shah Kotla             Delhi Daredevils
#
#                      team2                  toss_winner toss_decision  \
# 19   Kolkata Knight Riders  Royal Challengers Bangalore         field
# 239    Chennai Super Kings          Chennai Super Kings           bat
# 676       Rajasthan Royals             Rajasthan Royals           bat
#
#                     winner   result  result_margin  target_runs  target_overs  \
# 19   Kolkata Knight Riders     runs          140.0        223.0          20.0
# 239    Chennai Super Kings     runs           33.0        241.0          20.0
# 676       Delhi Daredevils  wickets            9.0        130.0          20.0
#
#     super_over method    umpire1         umpire2  is_final  match_id  inning  \
# 19           N    NaN  Asad Rauf     RE Koertzen         0    335982       1
# 239          N    NaN  MR Benson      SL Shastri         0    335983       1
# 676          N    NaN  Aleem Dar  GA Pratapkumar         0    335984       2
#
#               batting_team                 bowling_team  over  ball  \
# 19   Kolkata Knight Riders  Royal Challengers Bangalore     3     1
# 239    Chennai Super Kings              Kings XI Punjab     2     2
# 676       Delhi Daredevils             Rajasthan Royals    12     6
#
#           batter      bowler non_striker  batsman_runs  extra_runs  \
# 19   BB McCullum   AA Noffke  SC Ganguly             0           5
# 239    ML Hayden       B Lee    PA Patel             4           1
# 676     S Dhawan  D Salunkhe   G Gambhir             0           5
#
#      total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 19            5       wides          0              NaN        not out
# 239           5     noballs          0              NaN        not out
# 676           5       wides          0              NaN        not out
#
#     fielder                  matchup run_type  power_ball
# 19      NaN  BB McCullumv/sAA Noffke    other        True
# 239     NaN        ML Haydenv/sB Lee    other        True
# 676     NaN    S Dhawanv/sD Salunkhe    other       False

# %%
combined.run_type.unique()
# Out:
# <StringArray>
# ['single', 'dot', 'boundary', 'other', 'double']
# Length: 5, dtype: str
