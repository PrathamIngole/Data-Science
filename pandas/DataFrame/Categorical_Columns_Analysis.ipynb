# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
visa = pd.read_csv(r"C:\Users\prath\FullStackDataScience\my own folder\database\data_files\Visadataset.csv")
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
bank = pd.read_csv(r"C:\Users\prath\FullStackDataScience\my own folder\database\data_files\bank.csv", sep = ';' )
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ## Properties :
#
#             1. shape
#             2. size
#             3. head
#             4. tail
#             5. dtypes
#             6. info
#             7. descibe
#             8. isnull
#             9. columns
#             10. index

# %%
visa.shape
# Out:
# (25480, 12)

# %%
visa.size
# Out:
# 305760

# %%
visa.head(7)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
# 6  EZYV07      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# ...

# %%
visa.tail(6)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
# ...

# %%
visa.dtypes
# Out:
# case_id                      str
# continent                    str
# education_of_employee        str
# has_job_experience           str
# requires_job_training        str
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment         str
# prevailing_wage          float64
# unit_of_wage                 str
# full_time_position           str
# case_status                  str
# dtype: object

# %%
visa.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  str
#  1   continent              25480 non-null  str
#  2   education_of_employee  25480 non-null  str
#  3   has_job_experience     25480 non-null  str
#  4   requires_job_training  25480 non-null  str
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  str
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  str
#  10  full_time_position     25480 non-null  str
#  11  case_status            25480 non-null  str
# dtypes: float64(1), int64(2), str(9)
# memory usage: 2.3 MB

# %%
visa.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa.describe(include='all')
# Out:
#        case_id continent education_of_employee has_job_experience  \
# count    25480     25480                 25480              25480
# unique   25480         6                     4                  2
# top     EZYV01      Asia            Bachelor's                  Y
# freq         1     16861                 10234              14802
# mean       NaN       NaN                   NaN                NaN
# std        NaN       NaN                   NaN                NaN
# min        NaN       NaN                   NaN                NaN
# 25%        NaN       NaN                   NaN                NaN
# 50%        NaN       NaN                   NaN                NaN
# 75%        NaN       NaN                   NaN                NaN
# max        NaN       NaN                   NaN                NaN
#
#        requires_job_training  no_of_employees   yr_of_estab  \
# count                  25480     25480.000000  25480.000000
# ...

# %%
visa.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
visa.columns.tolist()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa[1:234:14]
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 1     EZYV02           Asia              Master's                  Y
# 15    EZYV16           Asia           High School                  Y
# 29    EZYV30           Asia            Bachelor's                  Y
# 43    EZYV44  North America              Master's                  Y
# 57    EZYV58           Asia            Bachelor's                  Y
# 71    EZYV72           Asia           High School                  Y
# 85    EZYV86           Asia              Master's                  Y
# 99   EZYV100           Asia              Master's                  N
# 113  EZYV114  North America           High School                  Y
# 127  EZYV128  North America            Bachelor's                  Y
# 141  EZYV142           Asia              Master's                  Y
# 155  EZYV156           Asia             Doctorate                  Y
# 169  EZYV170           Asia              Master's                  N
# ...

# %%
type(visa.columns)
# Out:
# pandas.Index

# %% [markdown]
# # select the particular series or data from the data frame :
#
#             - we have two methods :
#
#                          1. loc : for rows and columns name (location)
#                          2. iloc : for rows and columns by  numbers (position)
#
#
#                 **series** vs **Dataframe**
#
#                         + series and dataframe look

# %%
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa[3:153:34][["case_id", "has_job_experience", "requires_job_training"]]
# Out:
#      case_id has_job_experience requires_job_training
# 3     EZYV04                  N                     N
# 37    EZYV38                  Y                     Y
# 71    EZYV72                  Y                     N
# 105  EZYV106                  Y                     N
# 139  EZYV140                  Y                     N

# %%
# using iloc : 

visa.iloc[13: 664: 45, 4:7]
# Out:
#     requires_job_training  no_of_employees  yr_of_estab
# 13                      N             1652         2007
# 58                      N             3510         2007
# 103                     N              367         1982
# 148                     N             4273         1884
# 193                     N           128431         1991
# 238                     N             3592         1950
# 283                     Y              433         1912
# 328                     N             2234         1920
# 373                     N             3166         1995
# 418                     N             1363         1982
# 463                     N             3267         2001
# 508                     N             1446         2007
# 553                     N             1746         1984
# 598                     N            26957         1917
# 643                     N             3189         1838

# %%
visa.iloc[[100, 300, 38], [5]]
# Out:
#      no_of_employees
# 100             2227
# 300             3268
# 38              2206

# %%
visa.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='str')

# %%
visa.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa.values[100]
# Out:
# array(['EZYV101', 'Asia', "Master's", 'Y', 'N', 2227, 2007, 'Northeast',
#        28243.79, 'Year', 'Y', 'Certified'], dtype=object)

# %%
visa.iloc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa.iloc[[100]].keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='str')

# %%
visa.iloc[[105]].values
# Out:
# array([['EZYV106', 'North America', 'Doctorate', 'Y', 'N', 2317, 1995,
#         'Island', 41613.52, 'Year', 'Y', 'Certified']], dtype=object)

# %%
visa.iloc[100].index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='str')

# %%
visa.iloc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa.iloc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa.iloc[[100, 200, 300], ]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.iloc[[100, 200, 300], :]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.iloc[:, [3, 5, 7]].head()
# Out:
#   has_job_experience  no_of_employees region_of_employment
# 0                  N            14513                 West
# 1                  Y             2412            Northeast
# 2                  N            44444                 West
# 3                  N               98                 West
# 4                  Y             1082                South

# %%
visa.iloc[:, 3]
# Out:
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        Y
#         ..
# 25475    Y
# 25476    Y
# 25477    Y
# 25478    Y
# 25479    Y
# Name: has_job_experience, Length: 25480, dtype: str

# %%
visa.iloc[:, [3]]
# Out:
#       has_job_experience
# 0                      N
# 1                      Y
# 2                      N
# 3                      N
# 4                      Y
# ...                  ...
# 25475                  Y
# 25476                  Y
# 25477                  Y
# 25478                  Y
# 25479                  Y
#
# [25480 rows x 1 columns]

# %%
visa.iloc[:, :]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa[:, 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: (slice(None, None, None), 1)
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 visa[:, 1]
#
# ...

# %%
visa[:, [1]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:174, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), [1])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 visa[:, [1]]
#
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
# ...

# %%
visa.loc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa.loc[[100,399], ["case_id", "continent", "full_time_position"]]
# Out:
#      case_id continent full_time_position
# 100  EZYV101      Asia                  Y
# 399  EZYV400      Asia                  Y

# %%
visa.loc[100:105, 3:7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 visa.loc[100:105, 3:7]
#
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\indexing.py:1395, in _LocIndexer._getitem_tuple(self, tup)
#    1392 if self._multi_take_opportunity(tup):
#    1393     return self._multi_take(tup)
# -> 1395 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
visa.loc[100:105, "has_job_experience" : "region_of_employment"]
# Out:
#     has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 100                  Y                     N             2227         2007
# 101                  Y                     N              334         2007
# 102                  Y                     N              224         2008
# 103                  Y                     N              367         1982
# 104                  Y                     N              306         2003
# 105                  Y                     N             2317         1995
#
#     region_of_employment
# 100            Northeast
# 101              Midwest
# 102              Midwest
# 103                 West
# 104            Northeast
# 105               Island

# %%
visa.loc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa.loc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa.loc[[100, 200, 300], ]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.loc[[100, 200, 300], :]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.loc[:, ["requires_job_training", "has_job_experience" ]]
# Out:
#       requires_job_training has_job_experience
# 0                         N                  N
# 1                         N                  Y
# 2                         Y                  N
# 3                         N                  N
# 4                         N                  Y
# ...                     ...                ...
# 25475                     Y                  Y
# 25476                     N                  Y
# 25477                     N                  Y
# 25478                     Y                  Y
# 25479                     N                  Y
#
# [25480 rows x 2 columns]

# %%
visa.loc[:, "has_job_experience"]
# Out:
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        Y
#         ..
# 25475    Y
# 25476    Y
# 25477    Y
# 25478    Y
# 25479    Y
# Name: has_job_experience, Length: 25480, dtype: str

# %%
visa.loc[:, ["has_job_experience"]]
# Out:
#       has_job_experience
# 0                      N
# 1                      Y
# 2                      N
# 3                      N
# 4                      Y
# ...                  ...
# 25475                  Y
# 25476                  Y
# 25477                  Y
# 25478                  Y
# 25479                  Y
#
# [25480 rows x 1 columns]

# %%
visa.loc[:, :]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### dtypes :

# %%
visa.dtypes
# Out:
# case_id                      str
# continent                    str
# education_of_employee        str
# has_job_experience           str
# requires_job_training        str
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment         str
# prevailing_wage          float64
# unit_of_wage                 str
# full_time_position           str
# case_status                  str
# dtype: object

# %%
visa.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='str')

# %%
visa.dtypes.values
# Out:
# array([<StringDtype(storage='python', na_value=nan)>,
#        <StringDtype(storage='python', na_value=nan)>,
#        <StringDtype(storage='python', na_value=nan)>,
#        <StringDtype(storage='python', na_value=nan)>,
#        <StringDtype(storage='python', na_value=nan)>, dtype('int64'),
#        dtype('int64'), <StringDtype(storage='python', na_value=nan)>,
#        dtype('float64'), <StringDtype(storage='python', na_value=nan)>,
#        <StringDtype(storage='python', na_value=nan)>,
#        <StringDtype(storage='python', na_value=nan)>], dtype=object)

# %%
visa.dtypes.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='str')

# %%
df = pd.DataFrame(zip(visa.dtypes.keys(), visa.dtypes.values), columns = ["columns", "data_types"])

# %%
df
# Out:
#                   columns data_types
# 0                 case_id        str
# 1               continent        str
# 2   education_of_employee        str
# 3      has_job_experience        str
# 4   requires_job_training        str
# 5         no_of_employees      int64
# 6             yr_of_estab      int64
# 7    region_of_employment        str
# 8         prevailing_wage    float64
# 9            unit_of_wage        str
# 10     full_time_position        str
# 11            case_status        str

# %%
df1 = pd.DataFrame({ "index" : visa.dtypes.index,"data types" : visa.dtypes.values})
df1
# Out:
#                     index data types
# 0                 case_id        str
# 1               continent        str
# 2   education_of_employee        str
# 3      has_job_experience        str
# 4   requires_job_training        str
# 5         no_of_employees      int64
# 6             yr_of_estab      int64
# 7    region_of_employment        str
# 8         prevailing_wage    float64
# 9            unit_of_wage        str
# 10     full_time_position        str
# 11            case_status        str

# %%
cat_col = []
numerical = []
for i, j in zip(visa.dtypes.index, visa.dtypes.values) :
    if j == "str" :
        cat_col.append(i)
    else :
        numerical.append(i)

cat_col, numerical
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
df = pd.DataFrame({"cate" : cat_col, "numerical" : numerical})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df = pd.DataFrame({"cate" : cat_col, "numerical" : numerical})
#
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# ...

# %% [markdown]
# ## select types

# %%
visa.select_dtypes(exclude="str").columns, visa.select_dtypes(include=["str"]).columns.tolist()
# Out:
# (Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='str'),
#  ['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'])

# %% [markdown]
# ## Ways to select the columns :
#
#                     -   visa["columnName"]
#                     -   visa[["columnName"]]
#                     -   visa.columnName
#                     -   visa.iloc[:, 1]
#                     -   visa.iloc[:, [1]]
#                     -   visa.loc[:, "columnsNmae"]
#                     -   visa.loc[:, ["columnsNmae"]]

# %%
visa["continent"].head()
# Out:
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa
# Name: continent, dtype: str

# %%
visa[["continent"]].head()
# Out:
#   continent
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa

# %%
visa.continent.head()
# Out:
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa
# Name: continent, dtype: str

# %%
visa.iloc[:, 1].head()
# Out:
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa
# Name: continent, dtype: str

# %%
visa.iloc[:, [1]].head()
# Out:
#   continent
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa

# %%
visa.loc[:, "continent"].head()
# Out:
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa
# Name: continent, dtype: str

# %%
visa.loc[:, ["continent"]].head()
# Out:
#   continent
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa

# %% [markdown]
# ## Continent Column : single columns analysis

# %%
visa["continent"]
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: str

# %% [markdown]
# #### df.unique()

# %%
visa["continent"].unique()
# Out:
# <StringArray>
# ['Asia', 'Africa', 'North America', 'Europe', 'South America', 'Oceania']
# Length: 6, dtype: str

# %% [markdown]
# #### df.nunique()

# %%
visa["continent"].nunique()
# Out:
# 6

# %% [markdown]
# ##### select Asia continent

# %%
visa[visa["continent"] == "Asia"].index.size
# Out:
# 16861

# %%
pd.DataFrame({i : visa[visa["continent"] == i].index.size for i in visa["continent"].unique().tolist()}, index =[0])
# Out:
#     Asia  Africa  North America  Europe  South America  Oceania
# 0  16861     551           3292    3732            852      192

# %%
pd.DataFrame({"continent" : [i for i in visa["continent"].unique()], "count" : [visa[visa["continent"] == i].index.size for i in visa["continent"].unique()]})
# Out:
#        continent  count
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %% [markdown]
# #### value counts (frequency) :

# %%
visa["continent"].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
pd.DataFrame({"continent" : visa["continent"].value_counts().keys(), "count" : visa["continent"].value_counts().values}).sort_values(by = ["continent"])
# Out:
#        continent  count
# 4         Africa    551
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 5        Oceania    192
# 3  South America    852

# %%
count_continent
