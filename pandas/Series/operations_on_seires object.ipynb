# %%
import numpy as np
import pandas as pd

s = pd.Series(np.array(["Srinivas", "Pratik", "Raj", "Rossum", "Kinny", "Rajesh"]))

s.index = [f"Name{i+1}" for i in range(s.size)]

# %%
s
# Out:
# Name1    Srinivas
# Name2      Pratik
# Name3         Raj
# Name4      Rossum
# Name5       Kinny
# Name6      Rajesh
# dtype: str

# %%
# adding new values into the series : 
s["Name7"] = "Namam"

# %%
s
# Out:
# Name1    Srinivas
# Name2      Pratik
# Name3         Raj
# Name4      Rossum
# Name5       Kinny
# Name6      Rajesh
# Name7       Namam
# dtype: str

# %% [markdown]
# # adding two series object :

# %%
s1 = pd.Series(np.array([100, 200, 300, 400, 500]))
s2 = pd.Series(np.array([10, 20, 30, 40]))

# %% [markdown]
# ###  method 1

# %%
s1 + s2
# Out:
# 0    110.0
# 1    220.0
# 2    330.0
# 3    440.0
# 4      NaN
# dtype: float64

# %%
s3 = pd.Series(np.array([100, 200, 300, 400, 500]), index = ["a", "b", "c", "d", "e"]) 
s4 = pd.Series(np.array([10, 20, 30, 40, 50]), index = ["a", "b", "c", "d", "e"])
s3 + s4
# Out:
# a    110
# b    220
# c    330
# d    440
# e    550
# dtype: int64

# %%
s3 = pd.Series(np.array([100, 200, 300, 400, 500]), index = ["a", "b", "c", "d", "e"]) 
s4 = pd.Series(np.array([10, 20, 30, 40, 50]), index = ["j", "k", "l", "m", "n"])
s3 + s4
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# j   NaN
# k   NaN
# l   NaN
# m   NaN
# n   NaN
# dtype: float64

# %%
s3 = pd.Series(np.array([100, 200, 300, 400, 500]), index = ["a", "b", "c", "d", "e"]) 
s4 = pd.Series(np.array([10, 20, 30, 40, 50]), index = ["j", "k", "l", "m", "n"])
s4.add(s3, fill_value=0)
# Out:
# a    100.0
# b    200.0
# c    300.0
# d    400.0
# e    500.0
# j     10.0
# k     20.0
# l     30.0
# m     40.0
# n     50.0
# dtype: float64

# %% [markdown]
# ### method 2

# %%
s1.add(s2)
# Out:
# 0    110.0
# 1    220.0
# 2    330.0
# 3    440.0
# 4      NaN
# dtype: float64

# %%
s1.add(s2, fill_value=0)
# Out:
# 0    110.0
# 1    220.0
# 2    330.0
# 3    440.0
# 4    500.0
# dtype: float64

# %%
s3.add(s4)
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# j   NaN
# k   NaN
# l   NaN
# m   NaN
# n   NaN
# dtype: float64

# %% [markdown]
# ## Substraction of two Series Object

# %% [markdown]
# ### method 1

# %%
s1, s2
# Out:
# (0    100
#  1    200
#  2    300
#  3    400
#  4    500
#  dtype: int64,
#  0    10
#  1    20
#  2    30
#  3    40
#  dtype: int64)

# %%
s1 - s2
# Out:
# 0     90.0
# 1    180.0
# 2    270.0
# 3    360.0
# 4      NaN
# dtype: float64

# %%
s1.sub(s2, fill_value= 0 )
# Out:
# 0     90.0
# 1    180.0
# 2    270.0
# 3    360.0
# 4    500.0
# dtype: float64

# %% [markdown]
# ### method 2

# %% [markdown]
# ## droping the value of the series object

# %% [markdown]
# ### method 1

# %%
# seriesObj.drop(index)
s1, s2
# Out:
# (0    100
#  1    200
#  2    300
#  3    400
#  4    500
#  dtype: int64,
#  0    10
#  1    20
#  2    30
#  3    40
#  dtype: int64)

# %%
s1.drop(4)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
s1
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# Name: count, dtype: int64

# %%
s1.drop([4])
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# Name: count, dtype: int64

# %%
s1
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# Name: count, dtype: int64

# %%
s1.drop([4], inplace = True)

# %%
s1
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# Name: count, dtype: int64

# %% [markdown]
# ### method 2 : seriesObj.drop(labelName)

# %%
s1.name = "count"

# %%
s1.drop("count")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 s1.drop("count")
#
# File c:\Users\prath\FullStackDataScience\Data-Science\.venv\Lib\site-packages\pandas\core\series.py:5780, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5684 def drop(
#    5685     self,
#    5686     labels: IndexLabel | ListLike = None,
#    (...)   5693     errors: IgnoreRaise = "raise",
#    5694 ) -> Series | None:
#    5695     """
#    5696     Return Series with specified index labels removed.
#    5697
#    (...)   5778     dtype: float64
#    5779     """
# -> 5780     return super().drop(
#    5781         labels=labels,
#    5782         axis=axis,
#    5783         index=index,
#    5784         columns=columns,
#    5785         level=level,
#    5786         inplace=inplace,
#    5787         errors=errors,
#    5788     )
#
# ...

# %% [markdown]
# ## maximum / highest values :

# %% [markdown]
# ### method 1 :
#     - max()
#     - nlargest()

# %%
s1 = pd.Series([100, pd.NA, 300, None, 500, 600, np.nan, 800])
s1
# Out:
# 0     100
# 1    <NA>
# 2     300
# 3    None
# 4     500
# 5     600
# 6     NaN
# 7     800
# dtype: object

# %%
s1.isnull().sum()
# Out:
# np.int64(3)

# %%
s1.isna().sum()
# Out:
# np.int64(3)

# %%
s1.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
s1.nlar
