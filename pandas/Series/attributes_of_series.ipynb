# %% [markdown]
#             - name attribute

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([100, 'rossum', 34.54, 'Distinction'], index = ['ID', 'Name', "percentile", "status"], name = "Student")
print(s, type(s))
# name will give the name of the series.
# Out:
# ID                    100
# Name               rossum
# percentile          34.54
# status        Distinction
# Name: Student, dtype: object <class 'pandas.Series'>

# %%
#we can get name of series object by using seriesobj.name
print("series name : ", s.name)
# Out:
# series name :  Student

# %%
# we can also change the name of the series object  :
s.name = "stdnt"
print(s)
# Out:
# ID                    100
# Name               rossum
# percentile          34.54
# status        Distinction
# Name: stdnt, dtype: object

# %% [markdown]
#         - dimension

# %%
# find the dimension, shape by using ndim and shape attribute
print("dimension of series object : ", s.ndim)
print("Shape of series object : ", s.shape)
# Out:
# dimension of series object :  1
# Shape of series object :  (4,)

# %% [markdown]
#         - size

# %%
# find the number of values present in Series object (includes None, NaN, NA) :

s = pd.Series([1, 45, None, "rustum", pd.NA, 4.6, np.nan], name="altu faltu")
print("size of thee series : ", s.size)
print(s)
print("number of non None values : ", s.count())
print("number of None values : ", s.size - s.count())
# Out:
# size of thee series :  7
# 0         1
# 1        45
# 2      None
# 3    rustum
# 4      <NA>
# 5       4.6
# 6       NaN
# Name: altu faltu, dtype: object
# number of non None values :  4
# number of None values :  3

# %% [markdown]
#         - indices of the series

# %%
# when we don't give the index of series then it will give us the range
s = pd.Series([1, 45, None, "rustum", pd.NA, 4.6, np.nan], name="altu faltu")
print("size of thee series : ", s.size)
print(s)
print("index of the series ")
print(s.index)
# Out:
# size of thee series :  7
# 0         1
# 1        45
# 2      None
# 3    rustum
# 4      <NA>
# 5       4.6
# 6       NaN
# Name: altu faltu, dtype: object
# index of the series
# RangeIndex(start=0, stop=7, step=1)

# %%
# when we give the index of the series when initialization 
s = pd.Series([100, 'rossum', 34.54, 'Distinction'], index = ['ID', 'Name', "percentile", "status"], name = "Student")
print("size of thee series : ", s.size)
print(s)
print('series indices is : ')
print(s.index)
# Out:
# size of thee series :  4
# ID                    100
# Name               rossum
# percentile          34.54
# status        Distinction
# Name: Student, dtype: object
# series indices is :
# Index(['ID', 'Name', 'percentile', 'status'], dtype='str')

# %% [markdown]
#         - values

# %%
# the index of the series when initialization 
s = pd.Series([100, 'rossum', 34.54, 'Distinction'], index = ['ID', 'Name', "percentile", "status"], name = "Student")
print("size of thee series : ", s.size)
print(s)
print('series indices is : ')
print(s.values)
# Out:
# size of thee series :  4
# ID                    100
# Name               rossum
# percentile          34.54
# status        Distinction
# Name: Student, dtype: object
# series indices is :
# [100 'rossum' 34.54 'Distinction']

# %%
# or 
new_s = np.random.randint(1, 10, 5)
new_s
# Out:
# array([9, 9, 1, 8, 3], dtype=int32)

# %%
s = pd.Series(new_s, name = "random")
s
# Out:
# 0    9
# 1    9
# 2    1
# 3    8
# 4    3
# Name: random, dtype: int32

# %%
d = pd.DataFrame(np.random.randint(0, 30, (4, 3)), columns = ["h", "i", "y"], index=["ID1",pd.NA, "ID3", np.nan])
d
# Out:
#       h   i   y
# ID1   2  22   2
# NaN  20  19  15
# ID3  11  12  28
# NaN   9  11  21

# %% [markdown]
#                 - hasnans

# %%
d = d['i']
print(d)
d.hasnans
# Out:
# ID1    22
# NaN    19
# ID3    12
# NaN    11
# Name: i, dtype: int32
# False

# %%
d
# Out:
# ID1    22
# NaN    19
# ID3    12
# NaN    11
# Name: i, dtype: int32

# %% [markdown]
#                 - empty

# %%
print(d)
d.empty
# Out:
# ID1    22
# NaN    19
# ID3    12
# NaN    11
# Name: i, dtype: int32
# False

# %% [markdown]
#             - is_unique

# %%
d.is_unique
# Out:
# True

# %% [markdown]
#             - nbytes

# %%
d.nbytes
# Out:
# 16
