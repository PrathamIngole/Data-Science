# %% [markdown]
# **1D**

# %%
import numpy as np

# %%
l1 = [1, 2,3 ,4]
arr1 = np.array(l1)

# %%
arr1.shape
# Out:
# (4,)

# %%
arr1.size
# Out:
# 4

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr1.ndim
# Out:
# 1

# %% [markdown]
# ***2-D***

# %%
import numpy as np
l1 = [1, 2, 3]
l2 = [10, 20, 30]
l3 = [100, 200, 300]
arr = np.array([l1, l2, l3])

# %%
arr.shape
# Out:
# (3, 3)

# %%
arr.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 9

# %%
arr.dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Multi-Dimensiona**

# %%
l = [1, 2, 3]
l2 = [
        [50, 51, 53],
        [4, 5, 6]
    ]
l3 = [
        [
            [100, 99, 98],
            [97, 96, 95]
        ],
        [
            [7, 8, 9],
            [10, 11, 12]
        ]
    ]
l4 = [
        [
            [
                []
            ]

        ]
]
# Out:
# hello
