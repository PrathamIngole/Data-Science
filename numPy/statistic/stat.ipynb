# %% [markdown]
#             ***Statistic***
#
#
#     - mean
#     - median
#     - mode
#     - var
#     - std
#     - cov
#     - correlation
#     - percentile - quantile
#     - sum
#     - len
#     -  count

# %% [markdown]
# -- statictical method by numpy

# %%
import
