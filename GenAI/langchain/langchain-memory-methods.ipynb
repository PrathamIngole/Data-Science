# %% [markdown]
# # langchain

# %%
import langchain_core
langchain_core.__version__
# Out:
# '1.2.12'

# %%
import langchain_community
langchain_community.__version__
# Out:
# '0.4.1'

# %%
import langsmith
langsmith.__version__
# Out:
# '0.7.3'

# %%
import langchain
langchain.__version__
# Out:
# '1.2.10'

# %%
# !pip install langchain-community
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_core.prompts import PromptTemplate

# %%
from langchain_core.runnables import RunnableSequence
name_prompt = PromptTemplate(
    input_variables = ["product"], 
    template = "Provide a company name based on my {product}. "
)

seq1 = name_prompt | llm | (lambda x : x.content)

tag_line_prompt = PrompTemplate(
    input_variable = ["company name"], 
    template = "Provide a tag line based on my {compamny name}."
)

seq2 = tag_line_prompt | llm | (lambda x : x.content)

Sequence = RunnableSequence(seq1, seq2)


# Sequence = RunnableSequence(name_promt | LLM | (lambda x : x.content),
                        tag_line_prompt | LLM | 
print(Sequence.invoke("health care invoice details application."))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       1 from langchain_core.runnables import RunnableSequence
#       2 name_prompt = PromptTemplate(
#       3     input_variables = ["product"],
#       4     template = "Provide a company name based on my {product}. "
#       5 )
# ----> 7 seq1 = name_prompt | llm | (lambda x : x.content)
#       9 tag_line_prompt = PrompTemplate(
#      10     input_variable = ["company name"],
#      11     template = "Provide a tag line based on my {compamny name}."
#      12 )
#      14 seq2 = tag_line_prompt | llm | (lambda x : x.content)
#
# NameError: name 'llm' is not defined
